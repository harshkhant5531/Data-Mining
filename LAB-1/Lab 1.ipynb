# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Data Mining</b></center>
# <center><b><h1>Lab - 1</b></center>
# <pre>

# %% [markdown]
# # Introduction to Pandas Library Function:

# %% [markdown]
# # Step-1 Import the pandas Libraries

# %%
import pandas as pd

# %% [markdown]
# # Step-2 Import the dataset from this:....

# %%
ab=pd.read_csv('titanic.csv')

# %% [markdown]
# # Step-3 Read csv or excel File

# %%
ab=pd.read_csv('titanic.csv')

# %% [markdown]
# # Step-4 Print Data from csv or excel File

# %%
ab
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Step-5 See the First 10 Rows

# %%
ab.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # Step-6 See the Last 10 Rows

# %%
ab.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # Step-7 Data type of each columns

# %%
ab.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
ab.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#891 is total row count and 12 is column count 

ab.shape

#access the row or column
ab.shape[0]
# Out:
# 891

# %% [markdown]
# # Step-9 Access a specific column

# %%
#first way
ab['Name']

#second way
ab.Name

#Display multiple columns
ab[['Name','Age','Ticket']]
# Out:
#                                                   Name   Age            Ticket
# 0                              Braund, Mr. Owen Harris  22.0         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0          PC 17599
# 2                               Heikkinen, Miss. Laina  26.0  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0            113803
# 4                             Allen, Mr. William Henry  35.0            373450
# ..                                                 ...   ...               ...
# 886                              Montvila, Rev. Juozas  27.0            211536
# 887                       Graham, Miss. Margaret Edith  19.0            112053
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN        W./C. 6607
# 889                              Behr, Mr. Karl Howell  26.0            111369
# 890                                Dooley, Mr. Patrick  32.0            370376
#
# [891 rows x 3 columns]

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Step-10 Access rows by their integer location

# %%
ab.iloc[781]
# Out:
# PassengerId                                          782
# Survived                                               1
# Name           Dick, Mrs. Albert Adrian (Vera Gillespie)
# Sex                                               female
# SibSp                                                  1
# Parch                                                  0
# Ticket                                             17474
# Fare                                                57.0
# Cabin                                                B20
# Embarked                                               S
# PC                                               57000.0
# Name: 781, dtype: object

# %% [markdown]
# # Step-11 Delete a specific Column

# %%
#inplace use for permenent delete


df=pd.DataFrame(ab)
df.drop(columns=['Parch'],inplace=True)
df
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# # Step-12  Create a new Column

# %%
#we can add all row value same than use ab['PC']=5

ab['PC']=ab['Fare']*1000
ab
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# # Step-13  Perform Condition Selection on DataFrame

# %%
pd.DataFrame(ab.query('Cabin=="B42"')['Name'])

#another way
# pd.DataFrame(ab.query('Cabin=="B42"').name)
# Out:
#                              Name
# 887  Graham, Miss. Margaret Edith

# %% [markdown]
# # Step-14 Compute the sum of value

# %%
ab.Survived.sum()
# Out:
# 342

# %% [markdown]
# # Step-15 Compute the mean of value

# %%
ab.Survived.mean()
# Out:
# 0.3838383838383838

# %% [markdown]
# # Step-16 Count non-null value (column)

# %%
ab.Cabin.count()
# Out:
# 204

# %% [markdown]
# # Step-17 Find Minimun or Maximum values

# %%
#Min
minimum=ab.Survived.min()

#Max
maximum=ab.Survived.max()

print(minimum,maximum)
# Out:
# 0 1

# %%
#update the data of csv file
ab.to_csv('Pc.csv')

# %%
pd.DataFrame(ab.query('ab["PC"]>"7250.0"').name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\anaconda\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File D:\anaconda\Lib\collections\__init__.py:1015, in ChainMap.__getitem__(self, key)
#    1014         pass
# -> 1015 return self.__missing__(key)
#
# File D:\anaconda\Lib\collections\__init__.py:1007, in ChainMap.__missing__(self, key)
#    1006 def __missing__(self, key):
# -> 1007     raise KeyError(key)
#
# KeyError: 'ab'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
